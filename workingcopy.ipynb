# %%
import dash
import dash_html_components as html
from dash.dependencies import Input, Output
from markupsafe import Markup
from dash import dcc
import plotly.express as px
import pandas as pd
import numpy as np
from faker import Faker
import plotly.graph_objs as go
import geopandas as gpd
from shapely.geometry import Point
import folium
from folium.utilities import JsCode
from folium.features import GeoJsonPopup
from folium.plugins import TimeSliderChoropleth
from folium import plugins
from folium.plugins import HeatMap
# Out:
# /var/folders/c5/7b2hdd417y90r2mfyk9z39mw0000gn/T/ipykernel_97440/1066862009.py:2: UserWarning:
# The dash_html_components package is deprecated. Please replace
# `import dash_html_components as html` with `from dash import html`
#   import dash_html_components as html

# %%
# Set random seed for reproducibility
np.random.seed(0)

# Initialize Faker to generate fake data
fake = Faker()

# Define the number of rows in the dataset
num_rows = 15000

# Create a DataFrame to store the fake dataset
practice_df = pd.DataFrame()

closing_hour_range = range(17, 22)
opening_hour_range = range(7, 9)

practice_df['opening_hour_Monday'] = np.random.choice(opening_hour_range, size=num_rows)
practice_df['opening_hour_Tuesday'] = np.random.choice(opening_hour_range, size=num_rows)
practice_df['opening_hour_Wednesday'] = np.random.choice(opening_hour_range, size=num_rows)
practice_df['opening_hour_Thursday'] = np.random.choice(opening_hour_range, size=num_rows)
practice_df['opening_hour_Friday'] = np.random.choice(opening_hour_range, size=num_rows)
practice_df['opening_hour_Saturday'] = np.random.choice(opening_hour_range, size=num_rows)
practice_df['opening_hour_Sunday'] = np.random.choice(opening_hour_range, size=num_rows)

practice_df['closing_hour_Monday'] = np.random.choice(closing_hour_range, size=num_rows)
practice_df['closing_hour_Tuesday'] = np.random.choice(closing_hour_range, size=num_rows)
practice_df['closing_hour_Wednesday'] = np.random.choice(closing_hour_range, size=num_rows)
practice_df['closing_hour_Thursday'] = np.random.choice(closing_hour_range, size=num_rows)
practice_df['closing_hour_Friday'] = np.random.choice(closing_hour_range, size=num_rows)
practice_df['closing_hour_Saturday'] = np.random.choice(closing_hour_range, size=num_rows)
practice_df['closing_hour_Sunday'] = np.random.choice(closing_hour_range, size=num_rows)


# Categories for days of the week
daysofweek_categories = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

# Randomly choose days of the week for each row
practice_df['daysofweek'] = [np.random.choice(daysofweek_categories, size=np.random.randint(1, len(daysofweek_categories) + 1), replace=False) for _ in range(num_rows)]

# Create a matrix of zeros with the correct shape
matrix = np.zeros((num_rows, len(daysofweek_categories)), dtype=int)

# Fill the matrix based on the days in daysofweek
for i, days in enumerate(daysofweek):
    for day in days:
        day_index = daysofweek_categories.index(day)
        matrix[i, day_index] = 1

# Create a DataFrame from the matrix with appropriate column names
matrix_df = pd.DataFrame(matrix, columns=daysofweek_categories)

# Concatenate the matrix DataFrame with the practice DataFrame
practice_df = pd.concat([practice_df, matrix_df], axis=1)

# Generate random opacity values for each row in the DataFrame
opacity = np.random.uniform(0.1, 0.9, size=num_rows)


#Add opacity variable to data frame
practice_df['opacity'] = opacity

# Generate aed location variable
min_lat, max_lat = 49.9, 51.1  # Latitude boundaries of Belgium
min_lon, max_lon = 3, 6    # Longitude boundaries of Belgium
practice_df['Latitude'] = np.random.uniform(min_lat, max_lat, size=num_rows)
practice_df['Longitude'] = np.random.uniform(min_lon, max_lon, size=num_rows)
practice_df['aed_coordinates'] = list(zip(practice_df['Latitude'], practice_df['Longitude']))


aed_placement_categories = ['outside', 'inside', 'difficult']
aed_placement = np.random.choice(aed_placement_categories, size=num_rows)
practice_df['aed_placement'] = aed_placement


# Define buffer distances
buffer_distances = {
    'outside': 200,  # ~200 meters in degrees
    'inside': 150,   # ~150 meters in degrees
    'difficult': 125  # ~125 meters in degrees
}

practice_df['buffer_distance'] = practice_df['aed_placement'].map(buffer_distances)

print(practice_df.head())
# Out:
#    opening_hour_Monday  opening_hour_Tuesday  opening_hour_Wednesday  \
# 0                    7                     7                       8
# 1                    8                     8                       8
# 2                    8                     8                       7
# 3                    7                     7                       8
# 4                    8                     7                       7
#
#    opening_hour_Thursday  opening_hour_Friday  opening_hour_Saturday  \
# 0                      7                    7                      7
# 1                      8                    8                      8
# 2                      7                    7                      7
# 3                      7                    8                      8
# 4                      7                    8                      8
#
#    opening_hour_Sunday  closing_hour_Monday  closing_hour_Tuesday  \
# ...

# %%
# Initialize a dictionary to hold all the new columns
new_columns_dict = {}



# Loop through each day of the week and each hour
for day in daysofweek_categories:
    for hour in range(24):
        column_name = f'color_{day}_{hour}'
        opening_hour_col = f'opening_hour_{day}'
        closing_hour_col = f'closing_hour_{day}'
        
        # Create the condition for setting the color based on opening and closing hours for the specific day
        condition = (
            (practice_df[day] == 1) &  # Check if the day is in the matrix (daysofweek)
            (practice_df[opening_hour_col] <= hour) & 
            (practice_df[closing_hour_col] >= hour)
        )
        
        # Set the new column values based on the condition
        new_columns_dict[column_name] = np.where(condition, 'green', 'red')

# Add the new columns to the DataFrame
for column_name, column_values in new_columns_dict.items():
    practice_df[column_name] = column_values

practice_df.head()


# Convert DataFrame to GeoDataFrame
practice_gdf = gpd.GeoDataFrame(
    practice_df,
    geometry=[Point(xy) for xy in zip(practice_df['Longitude'], practice_df['Latitude'])],
    crs="EPSG:4326"  # WGS84 coordinate system
)


 
  

def generate_folium_map(selected_day, selected_hour):
    color_column = f'color_{selected_day}_{selected_hour}'
    practice_gdf['color'] = practice_df[color_column]

    m = folium.Map(location=[50.5, 4.3517], zoom_start=8)
    for idx, row in practice_gdf.iterrows():
        folium.Circle(
            location=(row['Latitude'], row['Longitude']),
            radius=row['buffer_distance'],
            color=row ['color'],
            fill=True,
            fill_opacity=row['opacity'],
            stroke=False
        ).add_to(m)
    return m.get_root().render()

app = dash.Dash(__name__)

app.layout = html.Div([
    dcc.RadioItems(
        id='day-radioitems',
        options=[{'label': day, 'value': day} for day in daysofweek_categories],
        value='Monday',
        inline=True
    ),
    dcc.Slider(
        id='time-slider',
        min=0,
        max=23,
        step=1,
        value=12,
        marks={i: str(i) for i in range(24)}
    ),
    html.Iframe(
        id='folium-map',
        srcDoc=generate_folium_map('Monday', 12),
        width='100%',
        height='600px'
    )
])

@app.callback(
    Output('folium-map', 'srcDoc'),
    [Input('day-radioitems', 'value'), Input('time-slider', 'value')]
)
def update_map(selected_day, selected_hour):
    return generate_folium_map(selected_day, selected_hour)

if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       2 new_columns_dict = {}
#       6 # Loop through each day of the week and each hour
# ----> 7 for day in daysofweek_categories:
#       8     for hour in range(24):
#       9         column_name = f'color_{day}_{hour}'
#
# NameError: name 'daysofweek_categories' is not defined

# %%
practice_df.head()
# Out:
#                               daysofweek  opening_hour  closing_hour  \
# 0                               [Sunday]             7            17
# 1  [Thursday, Wednesday, Monday, Friday]             8            20
# 2                             [Saturday]             8            18
# 3              [Tuesday, Monday, Sunday]             7            17
# 4                               [Sunday]             8            19
#
#     opacity   Latitude  Longitude                          aed_coordinates  \
# 0  0.763139  49.931571   4.542425   (49.93157130733513, 4.542425321018182)
# 1  0.615854  50.690467   4.715315   (50.69046678991123, 4.715314640932323)
# 2  0.121289  50.605940   5.857030   (50.60593963666725, 5.857029568510243)
# 3  0.797758  50.218796   5.870685   (50.21879610610471, 5.870684917307507)
# 4  0.114180  50.609178   5.911255  (50.609178439915546, 5.911255048526388)
#
#   aed_placement  buffer_distance color_Monday_0  ... color_Sunday_16  \
# ...
